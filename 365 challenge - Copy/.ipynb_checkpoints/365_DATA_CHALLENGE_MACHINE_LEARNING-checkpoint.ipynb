# %%
import pandas as pd
import numpy as np
import sqlalchemy as sql
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import cross_val_score
from statistics import mean

# %%
import torch
from sklearn import preprocessing
import deep_tabular_augmentation as dta
import warnings; warnings.simplefilter('ignore')

# %%
#creating a connection
con=sql.create_engine('mysql+pymysql://root:365pass@localhost:3306/365_database')

# %%
#read sql table
course_info=pd.read_sql_table('365_course_info',con)

# %%
data = pd.read_sql_query('SHOW TABLES;', con) 
  
# show first 5 table names
data
# Out:
#        Tables_in_365_database
# 0             365_course_info
# 1          365_course_ratings
# 2               365_exam_info
# 3               365_quiz_info
# 4      365_student_engagement
# 5           365_student_exams
# 6   365_student_hub_questions
# 7            365_student_info
# 8        365_student_learning
# 9       365_student_purchases
# 10        365_student_quizzes

# %%
course_ratings=pd.read_sql_table('365_course_ratings',con)
exam_info=pd.read_sql_table('365_exam_info',con)
quiz_info=pd.read_sql_table('365_quiz_info',con)
student_engagement=pd.read_sql_table('365_student_engagement',con)
student_exams=pd.read_sql_table('365_student_exams',con)
student_hub_questions=pd.read_sql_table('365_student_hub_questions',con)
student_info=pd.read_sql_table('365_student_info',con)
student_learning=pd.read_sql_table('365_student_learning',con)
student_purchases=pd.read_sql_table('365_student_purchases',con)
student_quizzes=pd.read_sql_table('365_student_quizzes',con)

# %%
student_info
# Out:
#        student_id student_country date_registered
# 0          258798              IN      2022-01-01
# 1          258799              CO      2022-01-01
# 2          258800              CA      2022-01-01
# 3          258801              IN      2022-01-01
# 4          258802              US      2022-01-01
# ...           ...             ...             ...
# 35225      295511              CM      2022-10-20
# 35226      295512              CA      2022-10-20
# 35227      295513              SA      2022-10-20
# 35228      295514              NL      2022-10-20
# 35229      295515              SG      2022-10-20
#
# [35230 rows x 3 columns]

# %%
student_learning
# Out:
#        student_id  course_id  minutes_watched date_watched
# 0          258798         23              0.3   2022-01-01
# 1          258800          2             12.9   2022-04-01
# 2          258800          7             46.8   2022-01-03
# 3          258800          7              4.3   2022-01-04
# 4          258800          7             31.7   2022-01-07
# ...           ...        ...              ...          ...
# 64530      295509         23              0.8   2022-10-20
# 64531      295510         53              0.1   2022-10-20
# 64532      295511          7              7.8   2022-10-20
# 64533      295512          7             10.4   2022-10-20
# 64534      295513         21              0.1   2022-10-20
#
# [64535 rows x 4 columns]

# %%
student_learning.nunique()
# Out:
# student_id         18167
# course_id             50
# minutes_watched     2215
# date_watched         293
# dtype: int64

# %%
student_purchases
# Out:
#       purchase_id  student_id purchase_type date_purchased
# 0           15781      258800        Annual     2022-01-01
# 1           15786      258803        Annual     2022-01-01
# 2           15808      258862        Annual     2022-01-01
# 3           15809      258865        Annual     2022-01-01
# 4           15811      258878        Annual     2022-01-01
# ...           ...         ...           ...            ...
# 3036        23148      278055       Monthly     2022-10-20
# 3037        23150      270103        Annual     2022-10-20
# 3038        23151      270824       Monthly     2022-10-20
# 3039        23152      295497       Monthly     2022-10-20
# 3040        23153      295506        Annual     2022-10-20
#
# [3041 rows x 4 columns]

# %%
student_purchases.nunique()
# Out:
# purchase_id       3041
# student_id        2135
# purchase_type        3
# date_purchased     293
# dtype: int64

# %%
result = pd.merge(student_info, student_purchases, how='inner',on = 'student_id')
result
# Out:
#       student_id student_country date_registered  purchase_id purchase_type  \
# 0         258800              CA      2022-01-01        15781        Annual
# 1         258803              US      2022-01-01        15786        Annual
# 2         258818              IN      2022-01-01        15845        Annual
# 3         258822              IN      2022-01-01        15941       Monthly
# 4         258832              IN      2022-01-01        17437       Monthly
# ...          ...             ...             ...          ...           ...
# 3036      295256              CA      2022-10-19        23106       Monthly
# 3037      295273              TR      2022-10-19        23111       Monthly
# 3038      295355              US      2022-10-19        23126        Annual
# 3039      295497              NL      2022-10-20        23152       Monthly
# 3040      295506              GB      2022-10-20        23153        Annual
#
#      date_purchased
# 0        2022-01-01
# 1        2022-01-01
# 2        2022-01-03
# 3        2022-01-09
# 4        2022-03-05
# ...             ...
# 3036     2022-10-19
# 3037     2022-10-19
# 3038     2022-10-19
# 3039     2022-10-20
# 3040     2022-10-20
#
# [3041 rows x 6 columns]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3041 entries, 0 to 3040
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   student_id       3041 non-null   int64
#  1   student_country  3041 non-null   object
#  2   date_registered  3041 non-null   datetime64[ns]
#  3   purchase_id      3041 non-null   int64
#  4   purchase_type    3041 non-null   object
#  5   date_purchased   3041 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(2), object(2)
# memory usage: 166.3+ KB

# %%
result.nunique()
# Out:
# student_id         2135
# student_country     118
# date_registered     292
# purchase_id        3041
# purchase_type         3
# date_purchased      293
# dtype: int64

# %%
result.purchase_type.value_counts()
# Out:
# Annual       1547
# Monthly      1444
# Quarterly      50
# Name: purchase_type, dtype: int64

# %%
(result.groupby('purchase_type').nunique())
# Out:
#                student_id  student_country  date_registered  purchase_id  \
# purchase_type
# Annual               1544              102              288         1547
# Monthly               611               88              249         1444
# Quarterly              38               17               34           50
#
#                date_purchased
# purchase_type
# Annual                    277
# Monthly                   284
# Quarterly                  45

# %%
#Understanding Annual, monthly and quarterly data

# %%
annual=result[result['purchase_type']=='Annual']

# %%
annual
# Out:
#       student_id student_country date_registered  purchase_id purchase_type  \
# 0         258800              CA      2022-01-01        15781        Annual
# 1         258803              US      2022-01-01        15786        Annual
# 2         258818              IN      2022-01-01        15845        Annual
# 5         258862              NL      2022-01-01        15808        Annual
# 6         258865              CA      2022-01-01        15809        Annual
# ...          ...             ...             ...          ...           ...
# 3032      294979              GB      2022-10-16        23065        Annual
# 3034      295106              US      2022-10-17        23107        Annual
# 3035      295214              GB      2022-10-18        23103        Annual
# 3038      295355              US      2022-10-19        23126        Annual
# 3040      295506              GB      2022-10-20        23153        Annual
#
#      date_purchased
# 0        2022-01-01
# 1        2022-01-01
# 2        2022-01-03
# 5        2022-01-01
# 6        2022-01-01
# ...             ...
# 3032     2022-10-16
# 3034     2022-10-19
# 3035     2022-10-18
# 3038     2022-10-19
# 3040     2022-10-20
#
# [1547 rows x 6 columns]

# %%
annual.student_id.value_counts()
# Out:
# 271197    2
# 264131    2
# 280121    2
# 268287    1
# 260813    1
#          ..
# 263535    1
# 261490    1
# 279923    1
# 265588    1
# 271951    1
# Name: student_id, Length: 1544, dtype: int64

# %%
annual[annual['student_id']==271197]
# Out:
#       student_id student_country date_registered  purchase_id purchase_type  \
# 1500      271197              ES      2022-04-18        18838        Annual
# 1501      271197              ES      2022-04-18        22659        Annual
#
#      date_purchased
# 1500     2022-04-25
# 1501     2022-09-29

# %%
annual[annual['student_id']==264131]
# Out:
#      student_id student_country date_registered  purchase_id purchase_type  \
# 695      264131              SA      2022-02-18        17226        Annual
# 696      264131              SA      2022-02-18        18183        Annual
#
#     date_purchased
# 695     2022-02-24
# 696     2022-03-31

# %%
annual[annual['student_id']==280121]
# Out:
#       student_id student_country date_registered  purchase_id purchase_type  \
# 2225      280121              CA      2022-07-02        20588        Annual
# 2226      280121              CA      2022-07-02        20907        Annual
#
#      date_purchased
# 2225     2022-07-05
# 2226     2022-07-18

# %%
plt.pie((annual.student_id.value_counts()).value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x1ee4d6839a0>,
#   <matplotlib.patches.Wedge at 0x1ee4d683e80>],
#  [Text(-1.0999795071101666, 0.006714457362684692, ''),
#   Text(1.0999795073827456, -0.006714412707942268, '')])

# %%
monthly=result[result['purchase_type']=='Monthly']

# %%
monthly
# Out:
#       student_id student_country date_registered  purchase_id purchase_type  \
# 3         258822              IN      2022-01-01        15941       Monthly
# 4         258832              IN      2022-01-01        17437       Monthly
# 9         258908              US      2022-01-01        15813       Monthly
# 13        258930              SA      2022-01-02        17124       Monthly
# 16        258956              IN      2022-01-02        18158       Monthly
# ...          ...             ...             ...          ...           ...
# 3030      294936              IN      2022-10-16        23080       Monthly
# 3033      295088              NL      2022-10-17        23096       Monthly
# 3036      295256              CA      2022-10-19        23106       Monthly
# 3037      295273              TR      2022-10-19        23111       Monthly
# 3039      295497              NL      2022-10-20        23152       Monthly
#
#      date_purchased
# 3        2022-01-09
# 4        2022-03-05
# 9        2022-01-01
# 13       2022-02-19
# 16       2022-03-31
# ...             ...
# 3030     2022-10-17
# 3033     2022-10-18
# 3036     2022-10-19
# 3037     2022-10-19
# 3039     2022-10-20
#
# [1444 rows x 6 columns]

# %%
monthly.student_id.value_counts()
# Out:
# 259965    10
# 259702    10
# 260465    10
# 263483     9
# 261491     9
#           ..
# 283730     1
# 265302     1
# 291949     1
# 275567     1
# 293497     1
# Name: student_id, Length: 611, dtype: int64

# %%
(monthly.student_id.value_counts()).value_counts()
# Out:
# 1     289
# 2     138
# 3      61
# 4      41
# 5      33
# 7      18
# 8      14
# 6       9
# 9       5
# 10      3
# Name: student_id, dtype: int64

# %%
monthly.groupby('student_id').nunique()
# Out:
#             student_country  date_registered  purchase_id  purchase_type  \
# student_id
# 258822                    1                1            1              1
# 258832                    1                1            1              1
# 258908                    1                1            1              1
# 258930                    1                1            1              1
# 258956                    1                1            4              1
# ...                     ...              ...          ...            ...
# 294936                    1                1            1              1
# 295088                    1                1            1              1
# 295256                    1                1            1              1
# 295273                    1                1            1              1
# 295497                    1                1            1              1
#
#             date_purchased
# student_id
# 258822                   1
# 258832                   1
# 258908                   1
# 258930                   1
# 258956                   4
# ...                    ...
# 294936                   1
# 295088                   1
# 295256                   1
# 295273                   1
# 295497                   1
#
# [611 rows x 5 columns]

# %%
# Plotting a bar graph of the Number of times a student made a monthly purchase
# in the column 'student_id'

monthly_count  = (monthly.student_id.value_counts()).value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(monthly_count.index, monthly_count.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('Number of times a student made a monthly purchase')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Monthly purchases', fontsize=12)
plt.show()

# %%
quarterly=result[result['purchase_type']=='Quarterly']

# %%
quarterly
# Out:
#       student_id student_country date_registered  purchase_id purchase_type  \
# 37        259171              US      2022-01-04        16459     Quarterly
# 157       260164              JM      2022-01-12        16023     Quarterly
# 158       260164              JM      2022-01-12        18449     Quarterly
# 160       260173              US      2022-01-12        16027     Quarterly
# 161       260173              US      2022-01-12        18481     Quarterly
# 162       260173              US      2022-01-12        20765     Quarterly
# 163       260173              US      2022-01-12        23003     Quarterly
# 359       261564              US      2022-01-25        18842     Quarterly
# 360       261564              US      2022-01-25        21084     Quarterly
# 371       261608              US      2022-01-26        16698     Quarterly
# 372       261608              US      2022-01-26        19021     Quarterly
# 373       261608              US      2022-01-26        21401     Quarterly
# 452       261979              NG      2022-01-29        16665     Quarterly
# 467       262221              IN      2022-02-01        17529     Quarterly
# 477       262270              US      2022-02-01        18675     Quarterly
# 515       262643              CA      2022-02-04        16764     Quarterly
# 527       262714              PH      2022-02-05        17129     Quarterly
# 528       262714              PH      2022-02-05        19403     Quarterly
# 553       262973              US      2022-02-07        16880     Quarterly
# 671       263888              US      2022-02-16        19387     Quarterly
# 716       264295              US      2022-02-20        19433     Quarterly
# 717       264295              US      2022-02-20        21747     Quarterly
# 762       264856              IN      2022-02-24        17416     Quarterly
# 1199      268863              ZA      2022-03-29        18694     Quarterly
# 1302      269796              IN      2022-04-06        18292     Quarterly
# 1385      270240              DE      2022-04-09        18408     Quarterly
# 1386      270240              DE      2022-04-09        20706     Quarterly
# 1547      271837              TN      2022-04-24        20252     Quarterly
# 1616      272596              BG      2022-05-02        20835     Quarterly
# 1621      272696              NL      2022-05-03        21423     Quarterly
# 1644      272977              US      2022-05-06        19223     Quarterly
# 1722      274166              US      2022-05-16        21982     Quarterly
# 2154      278890              DE      2022-06-22        20325     Quarterly
# 2203      279738              EC      2022-06-29        20491     Quarterly
# 2204      279738              EC      2022-06-29        22750     Quarterly
# 2244      280346              US      2022-07-05        20648     Quarterly
# 2254      280461              GB      2022-07-05        20603     Quarterly
# 2255      280461              GB      2022-07-05        22839     Quarterly
# 2275      280814              HK      2022-07-08        20664     Quarterly
# 2298      281074              US      2022-07-11        22968     Quarterly
# 2398      282442              IN      2022-07-23        21161     Quarterly
# 2406      282507              NG      2022-07-24        21941     Quarterly
# 2545      283745              US      2022-08-03        21438     Quarterly
# 2571      284241              TW      2022-08-07        21509     Quarterly
# 2620      285344              MY      2022-08-14        21653     Quarterly
# 2847      291400              AE      2022-09-20        22347     Quarterly
# 2848      291401              AE      2022-09-20        22348     Quarterly
# 2867      291626              GB      2022-09-22        22509     Quarterly
# 2894      292048              CA      2022-09-25        22963     Quarterly
# 2980      293251              NG      2022-10-04        22810     Quarterly
#
#      date_purchased
# 37       2022-01-25
# 157      2022-01-12
# 158      2022-04-12
# 160      2022-01-13
# 161      2022-04-13
# 162      2022-07-13
# 163      2022-10-13
# 359      2022-04-25
# 360      2022-07-25
# 371      2022-02-02
# 372      2022-05-02
# 373      2022-08-02
# 452      2022-01-31
# 467      2022-03-10
# 477      2022-04-19
# 515      2022-02-06
# 527      2022-02-20
# 528      2022-05-20
# 553      2022-02-09
# 671      2022-05-18
# 716      2022-05-20
# 717      2022-08-20
# 762      2022-03-04
# 1199     2022-04-20
# 1302     2022-04-06
# 1385     2022-04-10
# 1386     2022-07-10
# 1547     2022-06-18
# 1616     2022-07-16
# 1621     2022-08-04
# 1644     2022-05-11
# 1722     2022-08-31
# 2154     2022-06-22
# 2203     2022-06-30
# 2204     2022-09-30
# 2244     2022-07-08
# 2254     2022-07-05
# 2255     2022-10-05
# 2275     2022-07-08
# 2298     2022-10-12
# 2398     2022-07-26
# 2406     2022-08-29
# 2545     2022-08-04
# 2571     2022-08-08
# 2620     2022-08-16
# 2847     2022-09-20
# 2848     2022-09-20
# 2867     2022-09-25
# 2894     2022-10-12
# 2980     2022-10-04

# %%
quarterly.student_id.value_counts()
# Out:
# 260173    4
# 261608    3
# 279738    2
# 270240    2
# 261564    2
# 262714    2
# 260164    2
# 280461    2
# 264295    2
# 272596    1
# 280346    1
# 264856    1
# 284241    1
# 263888    1
# 272977    1
# 271837    1
# 282507    1
# 282442    1
# 291401    1
# 280814    1
# 293251    1
# 261979    1
# 268863    1
# 291626    1
# 262270    1
# 259171    1
# 269796    1
# 278890    1
# 292048    1
# 291400    1
# 262221    1
# 281074    1
# 262643    1
# 285344    1
# 274166    1
# 272696    1
# 262973    1
# 283745    1
# Name: student_id, dtype: int64

# %%
quaterly_count  = (quarterly.student_id.value_counts()).value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(quaterly_count.index, quaterly_count.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('Number of times a student made a Quarterly purchase')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Monthly purchases', fontsize=12)
plt.show()

# %%
#we can conclude that there are students who potentially make purchases after cancelling theri subscription and not many student continue with theri monthly and quarterly subscription for reasons outside the projects understanding

# %%
#finding the difference between registerd and paid dates
result['difference']=result.date_purchased-result.date_registered
result
# Out:
#       student_id student_country date_registered  purchase_id purchase_type  \
# 0         258800              CA      2022-01-01        15781        Annual
# 1         258803              US      2022-01-01        15786        Annual
# 2         258818              IN      2022-01-01        15845        Annual
# 3         258822              IN      2022-01-01        15941       Monthly
# 4         258832              IN      2022-01-01        17437       Monthly
# ...          ...             ...             ...          ...           ...
# 3036      295256              CA      2022-10-19        23106       Monthly
# 3037      295273              TR      2022-10-19        23111       Monthly
# 3038      295355              US      2022-10-19        23126        Annual
# 3039      295497              NL      2022-10-20        23152       Monthly
# 3040      295506              GB      2022-10-20        23153        Annual
#
#      date_purchased difference
# 0        2022-01-01     0 days
# 1        2022-01-01     0 days
# 2        2022-01-03     2 days
# 3        2022-01-09     8 days
# 4        2022-03-05    63 days
# ...             ...        ...
# 3036     2022-10-19     0 days
# 3037     2022-10-19     0 days
# 3038     2022-10-19     0 days
# 3039     2022-10-20     0 days
# 3040     2022-10-20     0 days
#
# [3041 rows x 7 columns]

# %%
(result.difference.value_counts())
# Out:
# 0 days      1021
# 1 days       233
# 2 days       132
# 4 days        82
# 7 days        79
#             ...
# 163 days       1
# 141 days       1
# 119 days       1
# 171 days       1
# 210 days       1
# Name: difference, Length: 197, dtype: int64

# %%
#Understanding the student engagement between free and paid students

# %%
df = pd.merge(student_info, student_purchases, how='outer',on = 'student_id')
df
# Out:
#        student_id student_country date_registered  purchase_id purchase_type  \
# 0          258798              IN      2022-01-01          NaN           NaN
# 1          258799              CO      2022-01-01          NaN           NaN
# 2          258800              CA      2022-01-01      15781.0        Annual
# 3          258801              IN      2022-01-01          NaN           NaN
# 4          258802              US      2022-01-01          NaN           NaN
# ...           ...             ...             ...          ...           ...
# 36131      295511              CM      2022-10-20          NaN           NaN
# 36132      295512              CA      2022-10-20          NaN           NaN
# 36133      295513              SA      2022-10-20          NaN           NaN
# 36134      295514              NL      2022-10-20          NaN           NaN
# 36135      295515              SG      2022-10-20          NaN           NaN
#
#       date_purchased
# 0                NaT
# 1                NaT
# 2         2022-01-01
# 3                NaT
# 4                NaT
# ...              ...
# 36131            NaT
# 36132            NaT
# 36133            NaT
# 36134            NaT
# 36135            NaT
#
# [36136 rows x 6 columns]

# %%
df.nunique()
# Out:
# student_id         35230
# student_country      181
# date_registered      293
# purchase_id         3041
# purchase_type          3
# date_purchased       293
# dtype: int64

# %% [markdown]
# 0-No_purhase
# 1-Annual
# 2-Monthly
# 3-Quarterly

# %%
'''df=df.replace({np.nan:0,'Annual':1,'Monthly':2,'Quarterly':3})
df'''
# Out:
# "df=df.replace({np.nan:0,'Annual':1,'Monthly':2,'Quarterly':3})\ndf"

# %%
df=df.replace({np.nan:0})
df
# Out:
#        student_id student_country      date_registered  purchase_id  \
# 0          258798              IN  2022-01-01 00:00:00          0.0
# 1          258799              CO  2022-01-01 00:00:00          0.0
# 2          258800              CA  2022-01-01 00:00:00      15781.0
# 3          258801              IN  2022-01-01 00:00:00          0.0
# 4          258802              US  2022-01-01 00:00:00          0.0
# ...           ...             ...                  ...          ...
# 36131      295511              CM  2022-10-20 00:00:00          0.0
# 36132      295512              CA  2022-10-20 00:00:00          0.0
# 36133      295513              SA  2022-10-20 00:00:00          0.0
# 36134      295514              NL  2022-10-20 00:00:00          0.0
# 36135      295515              SG  2022-10-20 00:00:00          0.0
#
#       purchase_type       date_purchased
# 0                 0                    0
# 1                 0                    0
# 2            Annual  2022-01-01 00:00:00
# 3                 0                    0
# 4                 0                    0
# ...             ...                  ...
# 36131             0                    0
# 36132             0                    0
# 36133             0                    0
# 36134             0                    0
# 36135             0                    0
#
# [36136 rows x 6 columns]

# %%
df['purchased']=""
for i in range(0,len(df)):
    if df['purchase_type'][i] in ('Annual','Monthly','Quarterly'):
        df['purchased'][i]='1'#yes purchase
    else:
        df['purchased'][i]='0'#not purchase

# %%
df
# Out:
#        student_id student_country      date_registered  purchase_id  \
# 0          258798              IN  2022-01-01 00:00:00          0.0
# 1          258799              CO  2022-01-01 00:00:00          0.0
# 2          258800              CA  2022-01-01 00:00:00      15781.0
# 3          258801              IN  2022-01-01 00:00:00          0.0
# 4          258802              US  2022-01-01 00:00:00          0.0
# ...           ...             ...                  ...          ...
# 36131      295511              CM  2022-10-20 00:00:00          0.0
# 36132      295512              CA  2022-10-20 00:00:00          0.0
# 36133      295513              SA  2022-10-20 00:00:00          0.0
# 36134      295514              NL  2022-10-20 00:00:00          0.0
# 36135      295515              SG  2022-10-20 00:00:00          0.0
#
#       purchase_type       date_purchased purchased
# 0                 0                    0         0
# 1                 0                    0         0
# 2            Annual  2022-01-01 00:00:00         1
# 3                 0                    0         0
# 4                 0                    0         0
# ...             ...                  ...       ...
# 36131             0                    0         0
# 36132             0                    0         0
# 36133             0                    0         0
# 36134             0                    0         0
# 36135             0                    0         0
#
# [36136 rows x 7 columns]

# %%
df.purchased.value_counts()
# Out:
# 0    33095
# 1     3041
# Name: purchased, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36136 entries, 0 to 36135
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   student_id       36136 non-null  int64
#  1   student_country  36136 non-null  object
#  2   date_registered  36136 non-null  object
#  3   purchase_id      36136 non-null  float64
#  4   purchase_type    36136 non-null  object
#  5   date_purchased   36136 non-null  object
#  6   purchased        36136 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 3.5+ MB

# %%
df=df.drop(['purchase_id'],axis=1)

# %%
df
# Out:
#        student_id student_country      date_registered purchase_type  \
# 0          258798              IN  2022-01-01 00:00:00             0
# 1          258799              CO  2022-01-01 00:00:00             0
# 2          258800              CA  2022-01-01 00:00:00        Annual
# 3          258801              IN  2022-01-01 00:00:00             0
# 4          258802              US  2022-01-01 00:00:00             0
# ...           ...             ...                  ...           ...
# 36131      295511              CM  2022-10-20 00:00:00             0
# 36132      295512              CA  2022-10-20 00:00:00             0
# 36133      295513              SA  2022-10-20 00:00:00             0
# 36134      295514              NL  2022-10-20 00:00:00             0
# 36135      295515              SG  2022-10-20 00:00:00             0
#
#             date_purchased purchased
# 0                        0         0
# 1                        0         0
# 2      2022-01-01 00:00:00         1
# 3                        0         0
# 4                        0         0
# ...                    ...       ...
# 36131                    0         0
# 36132                    0         0
# 36133                    0         0
# 36134                    0         0
# 36135                    0         0
#
# [36136 rows x 6 columns]

# %%
'''#CREATING A UNIQUE NUMBER FOR COUNTRY CODE
country_code=pd.DataFrame()
country_code['country']=df.student_country.unique()
country_code=country_code.reset_index()
country_code'''
# Out:
# "#CREATING A UNIQUE NUMBER FOR COUNTRY CODE\ncountry_code=pd.DataFrame()\ncountry_code['country']=df.student_country.unique()\ncountry_code=country_code.reset_index()\ncountry_code"

# %%
'''#replacing the student_country with numbers
for i in range(0,len(country_code)):
    df=df.replace(country_code['country'][i],country_code['index'][i])    

df'''
# Out:
# "#replacing the student_country with numbers\nfor i in range(0,len(country_code)):\n    df=df.replace(country_code['country'][i],country_code['index'][i])    \n\ndf"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36136 entries, 0 to 36135
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   student_id       36136 non-null  int64
#  1   student_country  36136 non-null  object
#  2   date_registered  36136 non-null  object
#  3   purchase_type    36136 non-null  object
#  4   date_purchased   36136 non-null  object
#  5   purchased        36136 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 3.2+ MB

# %%
df1=pd.merge(df, student_engagement,how='inner',on = 'student_id')

# %%
df1
# Out:
#        student_id student_country      date_registered purchase_type  \
# 0          258798              IN  2022-01-01 00:00:00             0
# 1          258800              CA  2022-01-01 00:00:00        Annual
# 2          258800              CA  2022-01-01 00:00:00        Annual
# 3          258800              CA  2022-01-01 00:00:00        Annual
# 4          258800              CA  2022-01-01 00:00:00        Annual
# ...           ...             ...                  ...           ...
# 88751      295509              EG  2022-10-20 00:00:00             0
# 88752      295510              IN  2022-10-20 00:00:00             0
# 88753      295511              CM  2022-10-20 00:00:00             0
# 88754      295512              CA  2022-10-20 00:00:00             0
# 88755      295513              SA  2022-10-20 00:00:00             0
#
#             date_purchased purchased  engagement_id  engagement_quizzes  \
# 0                        0         0         378673                   0
# 1      2022-01-01 00:00:00         1         110905                   1
# 2      2022-01-01 00:00:00         1         110906                   1
# 3      2022-01-01 00:00:00         1         110907                   1
# 4      2022-01-01 00:00:00         1         110908                   1
# ...                    ...       ...            ...                 ...
# 88751                    0         0        2648750                   0
# 88752                    0         0        2648820                   0
# 88753                    0         0        2648943                   1
# 88754                    0         0        2649150                   1
# 88755                    0         0        2649130                   0
#
#        engagement_exams  engagement_lessons date_engaged
# 0                     0                   1   2022-01-01
# 1                     0                   1   2022-01-03
# 2                     0                   1   2022-01-04
# 3                     1                   1   2022-01-05
# 4                     1                   1   2022-01-06
# ...                 ...                 ...          ...
# 88751                 0                   1   2022-10-20
# 88752                 0                   1   2022-10-20
# 88753                 0                   1   2022-10-20
# 88754                 0                   1   2022-10-20
# 88755                 0                   1   2022-10-20
#
# [88756 rows x 11 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88756 entries, 0 to 88755
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_id          88756 non-null  int64
#  1   student_country     88756 non-null  object
#  2   date_registered     88756 non-null  object
#  3   purchase_type       88756 non-null  object
#  4   date_purchased      88756 non-null  object
#  5   purchased           88756 non-null  object
#  6   engagement_id       88756 non-null  int64
#  7   engagement_quizzes  88756 non-null  int64
#  8   engagement_exams    88756 non-null  int64
#  9   engagement_lessons  88756 non-null  int64
#  10  date_engaged        88756 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(5)
# memory usage: 8.1+ MB

# %%
df1.purchased.value_counts()
# Out:
# 1    61098
# 0    27658
# Name: purchased, dtype: int64

# %%
df1=df1.reset_index(drop=True)

# %%
purchased=df1[df1['purchased']=='1']
not_purchased=df1[df1['purchased']=='0']

# %%
purchased
# Out:
#        student_id student_country      date_registered purchase_type  \
# 1          258800              CA  2022-01-01 00:00:00        Annual
# 2          258800              CA  2022-01-01 00:00:00        Annual
# 3          258800              CA  2022-01-01 00:00:00        Annual
# 4          258800              CA  2022-01-01 00:00:00        Annual
# 5          258800              CA  2022-01-01 00:00:00        Annual
# ...           ...             ...                  ...           ...
# 88563      295214              GB  2022-10-18 00:00:00        Annual
# 88605      295256              CA  2022-10-19 00:00:00       Monthly
# 88606      295256              CA  2022-10-19 00:00:00       Monthly
# 88676      295355              US  2022-10-19 00:00:00        Annual
# 88746      295497              NL  2022-10-20 00:00:00       Monthly
#
#             date_purchased purchased  engagement_id  engagement_quizzes  \
# 1      2022-01-01 00:00:00         1         110905                   1
# 2      2022-01-01 00:00:00         1         110906                   1
# 3      2022-01-01 00:00:00         1         110907                   1
# 4      2022-01-01 00:00:00         1         110908                   1
# 5      2022-01-01 00:00:00         1         110909                   1
# ...                    ...       ...            ...                 ...
# 88563  2022-10-18 00:00:00         1        2610436                   0
# 88605  2022-10-19 00:00:00         1        2615362                   1
# 88606  2022-10-19 00:00:00         1        2632288                   1
# 88676  2022-10-19 00:00:00         1        2628806                   0
# 88746  2022-10-20 00:00:00         1        2647407                   0
#
#        engagement_exams  engagement_lessons date_engaged
# 1                     0                   1   2022-01-03
# 2                     0                   1   2022-01-04
# 3                     1                   1   2022-01-05
# 4                     1                   1   2022-01-06
# 5                     0                   1   2022-01-10
# ...                 ...                 ...          ...
# 88563                 0                   1   2022-10-18
# 88605                 1                   1   2022-10-19
# 88606                 1                   1   2022-10-20
# 88676                 0                   1   2022-10-19
# 88746                 1                   1   2022-10-20
#
# [61098 rows x 11 columns]

# %%
purchased.engagement_exams.value_counts()
# Out:
# 0    43152
# 1    17946
# Name: engagement_exams, dtype: int64

# %%
engagement_exams  = purchased.engagement_exams.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_exams.index, engagement_exams.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
engagement_lessons = purchased.engagement_lessons.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_lessons.index, engagement_lessons.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
engagement_quizes = purchased.engagement_quizzes.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_quizes.index, engagement_quizes.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
#understanding purchased students pattern before making the purchase

# %%
purchased['difference']=purchased.date_purchased-purchased.date_registered

# %%
purchased
# Out:
#        student_id student_country      date_registered purchase_type  \
# 1          258800              CA  2022-01-01 00:00:00        Annual
# 2          258800              CA  2022-01-01 00:00:00        Annual
# 3          258800              CA  2022-01-01 00:00:00        Annual
# 4          258800              CA  2022-01-01 00:00:00        Annual
# 5          258800              CA  2022-01-01 00:00:00        Annual
# ...           ...             ...                  ...           ...
# 88563      295214              GB  2022-10-18 00:00:00        Annual
# 88605      295256              CA  2022-10-19 00:00:00       Monthly
# 88606      295256              CA  2022-10-19 00:00:00       Monthly
# 88676      295355              US  2022-10-19 00:00:00        Annual
# 88746      295497              NL  2022-10-20 00:00:00       Monthly
#
#             date_purchased purchased  engagement_id  engagement_quizzes  \
# 1      2022-01-01 00:00:00         1         110905                   1
# 2      2022-01-01 00:00:00         1         110906                   1
# 3      2022-01-01 00:00:00         1         110907                   1
# 4      2022-01-01 00:00:00         1         110908                   1
# 5      2022-01-01 00:00:00         1         110909                   1
# ...                    ...       ...            ...                 ...
# 88563  2022-10-18 00:00:00         1        2610436                   0
# 88605  2022-10-19 00:00:00         1        2615362                   1
# 88606  2022-10-19 00:00:00         1        2632288                   1
# 88676  2022-10-19 00:00:00         1        2628806                   0
# 88746  2022-10-20 00:00:00         1        2647407                   0
#
#        engagement_exams  engagement_lessons date_engaged difference
# 1                     0                   1   2022-01-03     0 days
# 2                     0                   1   2022-01-04     0 days
# 3                     1                   1   2022-01-05     0 days
# 4                     1                   1   2022-01-06     0 days
# 5                     0                   1   2022-01-10     0 days
# ...                 ...                 ...          ...        ...
# 88563                 0                   1   2022-10-18     0 days
# 88605                 1                   1   2022-10-19     0 days
# 88606                 1                   1   2022-10-20     0 days
# 88676                 0                   1   2022-10-19     0 days
# 88746                 1                   1   2022-10-20     0 days
#
# [61098 rows x 12 columns]

# %%
purchased.difference.value_counts()
# Out:
# 0 days      15106
# 1 days       5301
# 2 days       2749
# 4 days       1946
# 6 days       1636
#             ...
# 148 days        6
# 98 days         5
# 264 days        5
# 138 days        4
# 26 days         3
# Name: difference, Length: 197, dtype: int64

# %%
purchased_after=purchased[purchased['difference']>='1']

# %%
purchased_after
# Out:
#        student_id student_country      date_registered purchase_type  \
# 66         258818              IN  2022-01-01 00:00:00        Annual
# 67         258818              IN  2022-01-01 00:00:00        Annual
# 68         258818              IN  2022-01-01 00:00:00        Annual
# 69         258818              IN  2022-01-01 00:00:00        Annual
# 70         258818              IN  2022-01-01 00:00:00        Annual
# ...           ...             ...                  ...           ...
# 88463      295088              NL  2022-10-17 00:00:00       Monthly
# 88464      295088              NL  2022-10-17 00:00:00       Monthly
# 88465      295088              NL  2022-10-17 00:00:00       Monthly
# 88480      295106              US  2022-10-17 00:00:00        Annual
# 88481      295106              US  2022-10-17 00:00:00        Annual
#
#             date_purchased purchased  engagement_id  engagement_quizzes  \
# 66     2022-01-03 00:00:00         1         110928                   1
# 67     2022-01-03 00:00:00         1         110929                   1
# 68     2022-01-03 00:00:00         1         110930                   1
# 69     2022-01-03 00:00:00         1         110931                   1
# 70     2022-01-03 00:00:00         1         110932                   1
# ...                    ...       ...            ...                 ...
# 88463  2022-10-18 00:00:00         1        2591603                   1
# 88464  2022-10-18 00:00:00         1        2601609                   1
# 88465  2022-10-18 00:00:00         1        2619281                   1
# 88480  2022-10-19 00:00:00         1        2595932                   1
# 88481  2022-10-19 00:00:00         1        2615070                   1
#
#        engagement_exams  engagement_lessons date_engaged difference
# 66                    0                   1   2022-05-10     2 days
# 67                    0                   1   2022-03-13     2 days
# 68                    0                   1   2022-03-16     2 days
# 69                    0                   1   2022-03-17     2 days
# 70                    0                   1   2022-03-18     2 days
# ...                 ...                 ...          ...        ...
# 88463                 1                   1   2022-10-17     1 days
# 88464                 1                   1   2022-10-18     1 days
# 88465                 1                   1   2022-10-19     1 days
# 88480                 1                   1   2022-10-18     2 days
# 88481                 1                   1   2022-10-19     2 days
#
# [45992 rows x 12 columns]

# %%
engagement_exams  = purchased_after.engagement_exams.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_exams.index, engagement_exams.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('before purchase Enagement_exams')


engagement_lessons = purchased_after.engagement_lessons.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_lessons.index, engagement_lessons.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('before purchase Enagement_lessons')
engagement_quizes = purchased_after.engagement_quizzes.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_quizes.index, engagement_quizes.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('before purchase Enagement_quizzes')
# Out:
# Text(0.5, 1.0, 'before purchase Enagement_quizzes')

# %%
engagement_exams  = purchased.engagement_exams.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_exams.index, engagement_exams.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('after purchase Enagement_exams')


engagement_lessons = purchased.engagement_lessons.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_lessons.index, engagement_lessons.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('after purchase Enagement_lessons')
engagement_quizes = purchased.engagement_quizzes.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_quizes.index, engagement_quizes.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('after purchase Enagement_quizzes')
# Out:
# Text(0.5, 1.0, 'after purchase Enagement_quizzes')

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
purchased
# Out:
#        student_id student_country      date_registered purchase_type  \
# 1          258800              CA  2022-01-01 00:00:00        Annual
# 2          258800              CA  2022-01-01 00:00:00        Annual
# 3          258800              CA  2022-01-01 00:00:00        Annual
# 4          258800              CA  2022-01-01 00:00:00        Annual
# 5          258800              CA  2022-01-01 00:00:00        Annual
# ...           ...             ...                  ...           ...
# 88563      295214              GB  2022-10-18 00:00:00        Annual
# 88605      295256              CA  2022-10-19 00:00:00       Monthly
# 88606      295256              CA  2022-10-19 00:00:00       Monthly
# 88676      295355              US  2022-10-19 00:00:00        Annual
# 88746      295497              NL  2022-10-20 00:00:00       Monthly
#
#             date_purchased purchased  engagement_id  engagement_quizzes  \
# 1      2022-01-01 00:00:00         1         110905                   1
# 2      2022-01-01 00:00:00         1         110906                   1
# 3      2022-01-01 00:00:00         1         110907                   1
# 4      2022-01-01 00:00:00         1         110908                   1
# 5      2022-01-01 00:00:00         1         110909                   1
# ...                    ...       ...            ...                 ...
# 88563  2022-10-18 00:00:00         1        2610436                   0
# 88605  2022-10-19 00:00:00         1        2615362                   1
# 88606  2022-10-19 00:00:00         1        2632288                   1
# 88676  2022-10-19 00:00:00         1        2628806                   0
# 88746  2022-10-20 00:00:00         1        2647407                   0
#
#        engagement_exams  engagement_lessons date_engaged difference
# 1                     0                   1   2022-01-03     0 days
# 2                     0                   1   2022-01-04     0 days
# 3                     1                   1   2022-01-05     0 days
# 4                     1                   1   2022-01-06     0 days
# 5                     0                   1   2022-01-10     0 days
# ...                 ...                 ...          ...        ...
# 88563                 0                   1   2022-10-18     0 days
# 88605                 1                   1   2022-10-19     0 days
# 88606                 1                   1   2022-10-20     0 days
# 88676                 0                   1   2022-10-19     0 days
# 88746                 1                   1   2022-10-20     0 days
#
# [61098 rows x 12 columns]

# %%
before_purchase=purchased[purchased['difference']>='5']

# %%
before_purchase
# Out:
#        student_id student_country      date_registered purchase_type  \
# 66         258818              IN  2022-01-01 00:00:00        Annual
# 67         258818              IN  2022-01-01 00:00:00        Annual
# 68         258818              IN  2022-01-01 00:00:00        Annual
# 69         258818              IN  2022-01-01 00:00:00        Annual
# 70         258818              IN  2022-01-01 00:00:00        Annual
# ...           ...             ...                  ...           ...
# 88463      295088              NL  2022-10-17 00:00:00       Monthly
# 88464      295088              NL  2022-10-17 00:00:00       Monthly
# 88465      295088              NL  2022-10-17 00:00:00       Monthly
# 88480      295106              US  2022-10-17 00:00:00        Annual
# 88481      295106              US  2022-10-17 00:00:00        Annual
#
#             date_purchased purchased  engagement_id  engagement_quizzes  \
# 66     2022-01-03 00:00:00         1         110928                   1
# 67     2022-01-03 00:00:00         1         110929                   1
# 68     2022-01-03 00:00:00         1         110930                   1
# 69     2022-01-03 00:00:00         1         110931                   1
# 70     2022-01-03 00:00:00         1         110932                   1
# ...                    ...       ...            ...                 ...
# 88463  2022-10-18 00:00:00         1        2591603                   1
# 88464  2022-10-18 00:00:00         1        2601609                   1
# 88465  2022-10-18 00:00:00         1        2619281                   1
# 88480  2022-10-19 00:00:00         1        2595932                   1
# 88481  2022-10-19 00:00:00         1        2615070                   1
#
#        engagement_exams  engagement_lessons date_engaged difference
# 66                    0                   1   2022-05-10     2 days
# 67                    0                   1   2022-03-13     2 days
# 68                    0                   1   2022-03-16     2 days
# 69                    0                   1   2022-03-17     2 days
# 70                    0                   1   2022-03-18     2 days
# ...                 ...                 ...          ...        ...
# 88463                 1                   1   2022-10-17     1 days
# 88464                 1                   1   2022-10-18     1 days
# 88465                 1                   1   2022-10-19     1 days
# 88480                 1                   1   2022-10-18     2 days
# 88481                 1                   1   2022-10-19     2 days
#
# [45992 rows x 12 columns]

# %%
before_purchased_date=before_purchase.loc[(before_purchase['date_engaged']<before_purchase['date_purchased'])]
before_purchased_date
# Out:
#        student_id student_country      date_registered purchase_type  \
# 153        258822              IN  2022-01-01 00:00:00       Monthly
# 166        258832              IN  2022-01-01 00:00:00       Monthly
# 167        258832              IN  2022-01-01 00:00:00       Monthly
# 168        258832              IN  2022-01-01 00:00:00       Monthly
# 174        258832              IN  2022-01-01 00:00:00       Monthly
# ...           ...             ...                  ...           ...
# 88324      294907              FR  2022-10-16 00:00:00       Monthly
# 88352      294936              IN  2022-10-16 00:00:00       Monthly
# 88361      294949              US  2022-10-16 00:00:00        Annual
# 88463      295088              NL  2022-10-17 00:00:00       Monthly
# 88480      295106              US  2022-10-17 00:00:00        Annual
#
#             date_purchased purchased  engagement_id  engagement_quizzes  \
# 153    2022-01-09 00:00:00         1         166975                   0
# 166    2022-03-05 00:00:00         1         110960                   1
# 167    2022-03-05 00:00:00         1         110961                   1
# 168    2022-03-05 00:00:00         1         110962                   1
# 174    2022-03-05 00:00:00         1         378753                   0
# ...                    ...       ...            ...                 ...
# 88324  2022-10-17 00:00:00         1        2568681                   1
# 88352  2022-10-17 00:00:00         1        2573186                   1
# 88361  2022-10-17 00:00:00         1        2574806                   1
# 88463  2022-10-18 00:00:00         1        2591603                   1
# 88480  2022-10-19 00:00:00         1        2595932                   1
#
#        engagement_exams  engagement_lessons date_engaged difference
# 153                   1                   1   2022-01-01     8 days
# 166                   0                   1   2022-01-05    63 days
# 167                   0                   1   2022-01-06    63 days
# 168                   0                   1   2022-01-09    63 days
# 174                   0                   1   2022-01-01    63 days
# ...                 ...                 ...          ...        ...
# 88324                 0                   1   2022-10-16     1 days
# 88352                 0                   1   2022-10-16     1 days
# 88361                 0                   1   2022-10-16     1 days
# 88463                 1                   1   2022-10-17     1 days
# 88480                 1                   1   2022-10-18     2 days
#
# [16970 rows x 12 columns]

# %%
Country = (before_purchased_date.student_country.value_counts())

plt.figure(figsize=(15,10))
ax=sns.barplot(Country.index[:20], Country.values[:20], alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('Top 20 Countries that has most paid students engaged')
# Out:
# Text(0.5, 1.0, 'Top 20 Countries that has most paid students engaged')

# %%
engagement_exams  = before_purchased_date.engagement_exams.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_exams.index, engagement_exams.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('before purchase Enagement_exams')


engagement_lessons = before_purchased_date.engagement_lessons.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_lessons.index, engagement_lessons.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('before purchase Enagement_lessons')

engagement_quizes = before_purchased_date.engagement_quizzes.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_quizes.index, engagement_quizes.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('before purchase Enagement_quizzes')
# Out:
# Text(0.5, 1.0, 'before purchase Enagement_quizzes')

# %%
not_purchased
# Out:
#        student_id student_country      date_registered purchase_type  \
# 0          258798              IN  2022-01-01 00:00:00             0
# 49         258804              BD  2022-01-01 00:00:00             0
# 50         258807              US  2022-01-01 00:00:00             0
# 51         258809              ID  2022-01-01 00:00:00             0
# 52         258809              ID  2022-01-01 00:00:00             0
# ...           ...             ...                  ...           ...
# 88751      295509              EG  2022-10-20 00:00:00             0
# 88752      295510              IN  2022-10-20 00:00:00             0
# 88753      295511              CM  2022-10-20 00:00:00             0
# 88754      295512              CA  2022-10-20 00:00:00             0
# 88755      295513              SA  2022-10-20 00:00:00             0
#
#       date_purchased purchased  engagement_id  engagement_quizzes  \
# 0                  0         0         378673                   0
# 49                 0         0         110921                   1
# 50                 0         0         378694                   0
# 51                 0         0         110922                   1
# 52                 0         0         110923                   1
# ...              ...       ...            ...                 ...
# 88751              0         0        2648750                   0
# 88752              0         0        2648820                   0
# 88753              0         0        2648943                   1
# 88754              0         0        2649150                   1
# 88755              0         0        2649130                   0
#
#        engagement_exams  engagement_lessons date_engaged
# 0                     0                   1   2022-01-01
# 49                    0                   1   2022-01-01
# 50                    0                   1   2022-01-01
# 51                    0                   1   2022-01-02
# 52                    0                   1   2022-01-04
# ...                 ...                 ...          ...
# 88751                 0                   1   2022-10-20
# 88752                 0                   1   2022-10-20
# 88753                 0                   1   2022-10-20
# 88754                 0                   1   2022-10-20
# 88755                 0                   1   2022-10-20
#
# [27658 rows x 11 columns]

# %%
(not_purchased.student_country.value_counts())
# Out:
# IN    5207
# US    3397
# EG    2515
# NG    1581
# GB    1192
#       ...
# BI       1
# JE       1
# ME       1
# GU       1
# XK       1
# Name: student_country, Length: 172, dtype: int64

# %%
Country.index[:20]
# Out:
# Index(['US', 'CA', 'GB', 'IN', 'ES', 'SD', 'SG', 'BR', 'UA', 'NG', 'ZA', 'AE',
#        'EG', 'DE', 'SA', 'PL', 'LK', 'PK', 'NL', 'IT'],
#       dtype='object')

# %%
Country = (not_purchased.student_country.value_counts())

plt.figure(figsize=(15,10))
ax=sns.barplot(Country.index[:20], Country.values[:20], alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('Top 20 Countries that has most free students engaged')
# Out:
# Text(0.5, 1.0, 'Top 20 Countries that has most free students engaged')

# %%
engagement_exams  = not_purchased.engagement_exams.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_exams.index, engagement_exams.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
engagement_lessons = not_purchased.engagement_lessons.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_lessons.index, engagement_lessons.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
engagement_quizes = not_purchased.engagement_quizzes.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_quizes.index, engagement_quizes.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
#selecting random number of data to see if the student engagement was more before purchase, could be because the stduents liked the content

# %%
not_purchased_random = not_purchased.sample(n=len(before_purchased_date),replace=True)
not_purchased_random
# Out:
#        student_id student_country      date_registered purchase_type  \
# 80482      288095              IE  2022-08-25 00:00:00             0
# 41051      269522              NG  2022-04-03 00:00:00             0
# 9346       260940              IN  2022-01-19 00:00:00             0
# 88617      295264              LA  2022-10-19 00:00:00             0
# 47086      271434              EG  2022-04-21 00:00:00             0
# ...           ...             ...                  ...           ...
# 68526      280924              IN  2022-07-09 00:00:00             0
# 65223      279219              GB  2022-06-25 00:00:00             0
# 81366      288811              IN  2022-08-31 00:00:00             0
# 68849      281146              NG  2022-07-11 00:00:00             0
# 66458      279958              ES  2022-07-01 00:00:00             0
#
#       date_purchased purchased  engagement_id  engagement_quizzes  \
# 80482              0         0        1846636                   0
# 41051              0         0         388799                   0
# 9346               0         0         167472                   0
# 88617              0         0        2616161                   1
# 47086              0         0        1537373                   0
# ...              ...       ...            ...                 ...
# 68526              0         0         959202                   1
# 65223              0         0         775763                   1
# 81366              0         0        1961828                   1
# 68849              0         0        1074086                   1
# 66458              0         0        2179778                   0
#
#        engagement_exams  engagement_lessons date_engaged
# 80482                 0                   1   2022-08-25
# 41051                 0                   1   2022-04-03
# 9346                  1                   1   2022-01-20
# 88617                 0                   1   2022-10-19
# 47086                 0                   1   2022-08-16
# ...                 ...                 ...          ...
# 68526                 0                   1   2022-07-09
# 65223                 0                   1   2022-06-25
# 81366                 0                   1   2022-09-04
# 68849                 0                   1   2022-07-18
# 66458                 0                   1   2022-09-21
#
# [16970 rows x 11 columns]

# %%
Country = (not_purchased_random.student_country.value_counts())

plt.figure(figsize=(15,10))
ax=sns.barplot(Country.index[:20], Country.values[:20], alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('Top 20 Countries that has most free students engaged')
# Out:
# Text(0.5, 1.0, 'Top 20 Countries that has most free students engaged')

# %%
engagement_exams  = not_purchased_random.engagement_exams.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_exams.index, engagement_exams.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('free students Enagement_exams')


engagement_lessons = not_purchased_random.engagement_lessons.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_lessons.index, engagement_lessons.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('free students Enagement_lessons')

engagement_quizes = not_purchased_random.engagement_quizzes.value_counts()

plt.figure(figsize=(10,5))
ax=sns.barplot(engagement_quizes.index, engagement_quizes.values, alpha=0.8)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
plt.title('free students Enagement_quizzes')
# Out:
# Text(0.5, 1.0, 'free students Enagement_quizzes')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#the graph is similar of the free students after shuffling or selecting random data in general

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#concatening the before purchased data and random free students data

# %%
df3 = pd.concat([before_purchased_date, not_purchased_random])
df3
# Out:
#        student_id student_country      date_registered purchase_type  \
# 153        258822              IN  2022-01-01 00:00:00       Monthly
# 166        258832              IN  2022-01-01 00:00:00       Monthly
# 167        258832              IN  2022-01-01 00:00:00       Monthly
# 168        258832              IN  2022-01-01 00:00:00       Monthly
# 174        258832              IN  2022-01-01 00:00:00       Monthly
# ...           ...             ...                  ...           ...
# 68526      280924              IN  2022-07-09 00:00:00             0
# 65223      279219              GB  2022-06-25 00:00:00             0
# 81366      288811              IN  2022-08-31 00:00:00             0
# 68849      281146              NG  2022-07-11 00:00:00             0
# 66458      279958              ES  2022-07-01 00:00:00             0
#
#             date_purchased purchased  engagement_id  engagement_quizzes  \
# 153    2022-01-09 00:00:00         1         166975                   0
# 166    2022-03-05 00:00:00         1         110960                   1
# 167    2022-03-05 00:00:00         1         110961                   1
# 168    2022-03-05 00:00:00         1         110962                   1
# 174    2022-03-05 00:00:00         1         378753                   0
# ...                    ...       ...            ...                 ...
# 68526                    0         0         959202                   1
# 65223                    0         0         775763                   1
# 81366                    0         0        1961828                   1
# 68849                    0         0        1074086                   1
# 66458                    0         0        2179778                   0
#
#        engagement_exams  engagement_lessons date_engaged difference
# 153                   1                   1   2022-01-01     8 days
# 166                   0                   1   2022-01-05    63 days
# 167                   0                   1   2022-01-06    63 days
# 168                   0                   1   2022-01-09    63 days
# 174                   0                   1   2022-01-01    63 days
# ...                 ...                 ...          ...        ...
# 68526                 0                   1   2022-07-09        NaT
# 65223                 0                   1   2022-06-25        NaT
# 81366                 0                   1   2022-09-04        NaT
# 68849                 0                   1   2022-07-18        NaT
# 66458                 0                   1   2022-09-21        NaT
#
# [33940 rows x 12 columns]

# %%
df3=df3.sample(frac=1).reset_index(drop=True)
df3
# Out:
#        student_id student_country      date_registered purchase_type  \
# 0          276439              GB  2022-06-03 00:00:00       Monthly
# 1          283782              GB  2022-08-03 00:00:00             0
# 2          267721              SG  2022-03-17 00:00:00       Monthly
# 3          273212              PL  2022-05-08 00:00:00             0
# 4          273837              NG  2022-05-13 00:00:00             0
# ...           ...             ...                  ...           ...
# 33935      266325              US  2022-03-08 00:00:00       Monthly
# 33936      273582              US  2022-05-11 00:00:00             0
# 33937      277888              PK  2022-06-15 00:00:00             0
# 33938      283456              CA  2022-08-01 00:00:00       Monthly
# 33939      295078              LS  2022-10-17 00:00:00             0
#
#             date_purchased purchased  engagement_id  engagement_quizzes  \
# 0      2022-07-04 00:00:00         1         857599                   0
# 1                        0         0        1764361                   0
# 2      2022-06-18 00:00:00         1         117166                   1
# 3                        0         0         390933                   0
# 4                        0         0         120094                   1
# ...                    ...       ...            ...                 ...
# 33935  2022-04-08 00:00:00         1         386294                   0
# 33936                    0         0         391110                   0
# 33937                    0         0         693134                   1
# 33938  2022-10-05 00:00:00         1        1281374                   1
# 33939                    0         0        2605082                   0
#
#        engagement_exams  engagement_lessons date_engaged difference
# 0                     0                   1   2022-07-01    31 days
# 1                     0                   1   2022-08-20        NaT
# 2                     1                   1   2022-03-18    93 days
# 3                     0                   1   2022-05-08        NaT
# 4                     1                   1   2022-05-16        NaT
# ...                 ...                 ...          ...        ...
# 33935                 0                   1   2022-03-31    31 days
# 33936                 0                   1   2022-05-11        NaT
# 33937                 0                   1   2022-06-19        NaT
# 33938                 0                   1   2022-08-02    65 days
# 33939                 1                   1   2022-10-18        NaT
#
# [33940 rows x 12 columns]

# %%
df3=df3.drop(['student_id','engagement_id','date_registered','date_engaged',"date_purchased","difference"],axis=1)

# %%
#CREATING A UNIQUE NUMBER FOR COUNTRY CODE
country_code=pd.DataFrame()
country_code['country']=df3.student_country.unique()
country_code=country_code.reset_index()
country_code
# Out:
#      index country
# 0        0      GB
# 1        1      SG
# 2        2      PL
# 3        3      NG
# 4        4      LY
# ..     ...     ...
# 152    152      AG
# 153    153      ME
# 154    154      NI
# 155    155      TD
# 156    156      PY
#
# [157 rows x 2 columns]

# %%
#replacing the student_country with numbers
for i in range(0,len(country_code)):
    df3=df3.replace(country_code['country'][i],country_code['index'][i])    

df3
# Out:
#        student_country purchase_type purchased  engagement_quizzes  \
# 0                    0       Monthly         1                   0
# 1                    0             0         0                   0
# 2                    1       Monthly         1                   1
# 3                    2             0         0                   0
# 4                    3             0         0                   1
# ...                ...           ...       ...                 ...
# 33935                6       Monthly         1                   0
# 33936                6             0         0                   0
# 33937                8             0         0                   1
# 33938                7       Monthly         1                   1
# 33939              115             0         0                   0
#
#        engagement_exams  engagement_lessons
# 0                     0                   1
# 1                     0                   1
# 2                     1                   1
# 3                     0                   1
# 4                     1                   1
# ...                 ...                 ...
# 33935                 0                   1
# 33936                 0                   1
# 33937                 0                   1
# 33938                 0                   1
# 33939                 1                   1
#
# [33940 rows x 6 columns]

# %%
df3=df3.replace({np.nan:0,'Annual':1,'Monthly':2,'Quarterly':3})

# %%
df3
# Out:
#        student_country  purchase_type purchased  engagement_quizzes  \
# 0                    0              2         1                   0
# 1                    0              0         0                   0
# 2                    1              2         1                   1
# 3                    2              0         0                   0
# 4                    3              0         0                   1
# ...                ...            ...       ...                 ...
# 33935                6              2         1                   0
# 33936                6              0         0                   0
# 33937                8              0         0                   1
# 33938                7              2         1                   1
# 33939              115              0         0                   0
#
#        engagement_exams  engagement_lessons
# 0                     0                   1
# 1                     0                   1
# 2                     1                   1
# 3                     0                   1
# 4                     1                   1
# ...                 ...                 ...
# 33935                 0                   1
# 33936                 0                   1
# 33937                 0                   1
# 33938                 0                   1
# 33939                 1                   1
#
# [33940 rows x 6 columns]

# %%
df3.corr()
# Out:
#                     student_country  purchase_type  engagement_quizzes  \
# student_country            1.000000      -0.159511           -0.003934
# purchase_type             -0.159511       1.000000            0.079354
# engagement_quizzes        -0.003934       0.079354            1.000000
# engagement_exams          -0.039087       0.226752            0.125267
# engagement_lessons        -0.005581       0.020397            0.044922
#
#                     engagement_exams  engagement_lessons
# student_country            -0.039087           -0.005581
# purchase_type               0.226752            0.020397
# engagement_quizzes          0.125267            0.044922
# engagement_exams            1.000000           -0.186452
# engagement_lessons         -0.186452            1.000000

# %%
f,ax = plt.subplots(figsize=(14,12))
sns.heatmap(df3.corr(), cmap="PiYG", annot=True, linewidths=0.5, fmt= '.1f',ax=ax)
plt.show()

# %%
df3.nunique()
# Out:
# student_country       157
# purchase_type           4
# purchased               2
# engagement_quizzes      2
# engagement_exams        2
# engagement_lessons      2
# dtype: int64

# %%
df3.purchased.value_counts()[:20].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33940 entries, 0 to 33939
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_country     33940 non-null  int64
#  1   purchase_type       33940 non-null  int64
#  2   purchased           33940 non-null  object
#  3   engagement_quizzes  33940 non-null  int64
#  4   engagement_exams    33940 non-null  int64
#  5   engagement_lessons  33940 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 1.6+ MB

# %%
df3
# Out:
#        student_country  purchase_type purchased  engagement_quizzes  \
# 0                    0              2         1                   0
# 1                    0              0         0                   0
# 2                    1              2         1                   1
# 3                    2              0         0                   0
# 4                    3              0         0                   1
# ...                ...            ...       ...                 ...
# 33935                6              2         1                   0
# 33936                6              0         0                   0
# 33937                8              0         0                   1
# 33938                7              2         1                   1
# 33939              115              0         0                   0
#
#        engagement_exams  engagement_lessons
# 0                     0                   1
# 1                     0                   1
# 2                     1                   1
# 3                     0                   1
# 4                     1                   1
# ...                 ...                 ...
# 33935                 0                   1
# 33936                 0                   1
# 33937                 0                   1
# 33938                 0                   1
# 33939                 1                   1
#
# [33940 rows x 6 columns]

# %%
df3.describe()
# Out:
#        student_country  purchase_type  engagement_quizzes  engagement_exams  \
# count     33940.000000   33940.000000        33940.000000      33940.000000
# mean         19.047731       0.963288            0.368503          0.216323
# std          23.068677       0.999960            0.482406          0.411743
# min           0.000000       0.000000            0.000000          0.000000
# 25%           6.000000       0.000000            0.000000          0.000000
# 50%           7.000000       0.500000            0.000000          0.000000
# 75%          26.000000       2.000000            1.000000          0.000000
# max         156.000000       3.000000            1.000000          1.000000
#
#        engagement_lessons
# count        33940.000000
# mean             0.984708
# std              0.122712
# min              0.000000
# 25%              1.000000
# 50%              1.000000
# 75%              1.000000
# max              1.000000

# %%
X=df3.drop(['purchased'],axis=1)
y=df3['purchased']

# %%
noise = np.random.normal(0, 1, [2,2]) 
print(noise)

# %%
from sklearn.metrics import RocCurveDisplay
ax = plt.gca()
rfc_disp = RocCurveDisplay.from_estimator(tree, X_test, y_test, ax=ax, alpha=0.8)

plt.show()

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test, tree.predict(X_test))

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, cross_val_score
clf = DecisionTreeClassifier(random_state=42)

k_folds = KFold(n_splits = 10)

scores = cross_val_score(clf, X_test, y_test, cv = k_folds)

print("Cross Validation Scores: ", scores)
print("Average CV Score: ", scores.mean())
print("Number of CV Scores used in Average: ", len(scores))

# %%
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
kf = KFold(n_splits=10)
mae_train = []
mae_test = []
for train_index, test_index in kf.split(X):
    
   X_train, X_test = X.iloc[train_index], X.iloc[test_index]
   y_train, y_test = y[train_index], y[test_index]
   model = DecisionTreeClassifier(random_state=42)
   model.fit(X_train, y_train)
   y_train_pred = model.predict(X_train)
   y_test_pred = model.predict(X_test)
   mae_train.append(mean_absolute_error(y_train, y_train_pred))
   mae_test.append(mean_absolute_error(y_test, y_test_pred))

# %%
folds = range(1, kf.get_n_splits() + 1)
plt.plot(folds, mae_train, 'o-', color='green', label='train')
plt.plot(folds, mae_test, 'o-', color='red', label='test')
plt.legend()
plt.grid()
plt.xlabel('Number of fold')
plt.ylabel('Mean Absolute Error')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, tree.predict(X_test), squared=False)

# %%
validation_targets

# %%
accuracy_score(validation_targets, tree.predict(validation_inputs))

# %%
y_predict=tree.predict(validation_inputs)
prediction=pd.DataFrame()
prediction['predicted_targets']=y_predict
prediction['validation_targets']=np.nan_to_num(validation_targets)
prediction

# %%
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
#
# Create an instance of Pipeline
#
pipeline = make_pipeline(StandardScaler(), RandomForestClassifier(n_estimators=100, max_depth=4))
#
# Create an instance of StratifiedKFold which can be used to get indices of different training and test folds
#
strtfdKFold = StratifiedKFold(n_splits=10)
kfold = strtfdKFold.split(X_train, y_train)
scores = []
#
#
#
for k, (train, test) in enumerate(kfold):
    pipeline.fit(X_train.iloc[train, :], y_train.iloc[train])
    score = pipeline.score(X_train.iloc[test, :], y_train.iloc[test])
    scores.append(score)
    print('Fold: %2d, Training/Test Split Distribution: %s, Accuracy: %.3f' % (k+1, np.bincount(y_train.iloc[train]), score))
 
print('\n\nCross-Validation accuracy: %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))
